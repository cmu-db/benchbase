# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
cockroach_single_node_df = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/cockroach/results_tpcc_cockroach_1h_3_and_1_node/tpcc_2024-04-21_11-59-28.results.csv')
cockroach_three_nodes_df = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/cockroach/results_tpcc_cockroach_1h_3_and_1_node/tpcc_2024-04-21_10-25-41.results.csv')

# Plotting throughput
plt.figure(figsize=(10, 5))

# Plot throughput for three nodes
plt.plot(cockroach_three_nodes_df['Time (seconds)'], cockroach_three_nodes_df['Throughput (requests/second)'],
         color='blue', linestyle='-', label='Throughput - Three Nodes')

# Plot throughput for single node
plt.plot(cockroach_single_node_df['Time (seconds)'], cockroach_single_node_df['Throughput (requests/second)'],
         color='red', linestyle='-', label='Throughput - Single Node')

plt.xlabel('Time (seconds)')
plt.ylabel('Throughput (requests/second)')
plt.title('Throughput Comparison')
plt.legend()
plt.grid(True)
plt.show()

# Plotting latency
plt.figure(figsize=(10, 5))

# Plot average latency for three nodes
plt.plot(cockroach_three_nodes_df['Time (seconds)'], cockroach_three_nodes_df['Average Latency (millisecond)'],
         color='blue', linestyle='-', label='Average Latency - Three Nodes')

# Plot average latency for single node
plt.plot(cockroach_single_node_df['Time (seconds)'], cockroach_single_node_df['Average Latency (millisecond)'],
         color='red', linestyle='-', label='Average Latency - Single Node')

plt.xlabel('Time (seconds)')
plt.ylabel('Latency (millisecond)')
plt.title('Latency Comparison')
plt.legend()
plt.grid(True)
plt.show()

# %%
#oracle_local_df 
oracle_local_df = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_rdbms/results_oracle_tpcc_1h_1w/tpcc_2024-04-25_17-14-10.results.csv')
# oracle_autonomous_df 
oracle_autonomous_df = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_1w_1h_auto/tpcc_2024-04-24_08-19-56.results.csv')

# Plotting throughput
plt.figure(figsize=(10, 5))

# Plot throughput for three nodes
plt.plot(oracle_local_df['Time (seconds)'], oracle_local_df['Throughput (requests/second)'],
         color='blue', linestyle='-', label='Throughput - Oracle Local')

# Plot throughput for single node
plt.plot(oracle_autonomous_df['Time (seconds)'], oracle_autonomous_df['Throughput (requests/second)'],
         color='red', linestyle='-', label='Throughput - Oracle Autonomous DB')

plt.xlabel('Time (seconds)')
plt.ylabel('Throughput (requests/second)')
plt.title('Throughput Comparison')
plt.legend()
plt.grid(True)
plt.show()

# Plotting latency
plt.figure(figsize=(10, 5))

# Plot average latency for three nodes
plt.plot(oracle_local_df['Time (seconds)'], oracle_local_df['Average Latency (millisecond)'],
         color='blue', linestyle='-', label='Average Latency - Oracle Local')

# Plot average latency for single node
plt.plot(oracle_autonomous_df['Time (seconds)'], oracle_autonomous_df['Average Latency (millisecond)'],
         color='red', linestyle='-', label='Average Latency - Oracle Autonomous DB')

plt.xlabel('Time (seconds)')
plt.ylabel('Latency (millisecond)')
plt.title('Latency Comparison')
plt.legend()
plt.grid(True)
plt.show()

# %%
#oracle_autonomous_df_transaction_read-commited
oracle_autonomous_df_read_commited = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_1h_10w_TRANSACTION_READ_COMMITTED/tpcc_2024-04-26_12-31-41.results.csv')
# oracle_autonomous_df
oracle_autonomous_df_serializable = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_10w_1h_auto/tpcc_2024-04-26_01-54-28.results.csv')

# Plotting throughput
plt.figure(figsize=(10, 5))

# Plot throughput for three nodes
plt.plot(oracle_autonomous_df_read_commited['Time (seconds)'], oracle_autonomous_df_read_commited['Throughput (requests/second)'],
         color='blue', linestyle='-', label='Throughput - Oracle Autonomous DB TRANSACTION_READ_COMMITTED')
# Plot throughput for single node
plt.plot(oracle_autonomous_df_serializable['Time (seconds)'], oracle_autonomous_df_serializable['Throughput (requests/second)'],
         color='red', linestyle='-', label='Throughput - Oracle Autonomous DB TRANSACTION_SERIALIZABLE')

plt.xlabel('Time (seconds)')
plt.ylabel('Throughput (requests/second)')
plt.title('Throughput Comparison')
plt.legend()
plt.grid(True)
plt.show()

# Plotting latency
plt.figure(figsize=(10, 5))

# Plot average latency for three nodes
plt.plot(oracle_autonomous_df_read_commited['Time (seconds)'], oracle_autonomous_df_read_commited['Average Latency (millisecond)'],
         color='blue', linestyle='-', label='Average Latency - Oracle Autonomous DB TRANSACTION_READ_COMMITTED')

# Plot average latency for single node
plt.plot(oracle_autonomous_df_serializable['Time (seconds)'], oracle_autonomous_df_serializable['Average Latency (millisecond)'],
         color='red', linestyle='-', label='Average Latency - Oracle Autonomous DB TRANSACTION_SERIALIZABLE')

plt.xlabel('Time (seconds)')
plt.ylabel('Latency (millisecond)')
plt.title('Latency Comparison')
plt.legend()
plt.grid(True)
plt.show()

# %%
#oracle_autonomous_df_1w
oracle_autonomous_df_1w = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_1w_1h_auto/tpcc_2024-04-24_08-19-56.results.csv')
# oracle_autonomous_df_10w
oracle_autonomous_df_10w = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_10w_1h_auto/tpcc_2024-04-26_01-54-28.results.csv')
# oracle_autonomous_df_100w
oracle_autonomous_df_100w = pd.read_csv('/home/preethi/Documents/DB project/benchbase/results/DB results/oracle_auto/results_oracle_100w_1h_auto/tpcc_2024-04-26_10-13-26.results.csv')

# Plotting throughput
plt.figure(figsize=(10, 5))

# Plot throughput for three nodes
plt.plot(oracle_autonomous_df_1w['Time (seconds)'], oracle_autonomous_df_1w['Throughput (requests/second)'],
         color='blue', linestyle='-', label='Throughput - Oracle Autonomous DB Scale Factor=1')

# Plot throughput for single node
plt.plot(oracle_autonomous_df_10w['Time (seconds)'], oracle_autonomous_df_10w['Throughput (requests/second)'],
         color='red', linestyle='-', label='Throughput - Oracle Autonomous DB Scale Factor=10')

plt.plot(oracle_autonomous_df_100w['Time (seconds)'], oracle_autonomous_df_100w['Throughput (requests/second)'],
         color='green', linestyle='-', label='Throughput - Oracle Autonomous DB Scale Factor=100')

plt.xlabel('Time (seconds)')
plt.ylabel('Throughput (requests/second)')
plt.title('Throughput Comparison')
plt.legend()
plt.grid(True)
plt.show()

# Plotting latency
plt.figure(figsize=(10, 5))

# Plot average latency for three nodes
plt.plot(oracle_autonomous_df_1w['Time (seconds)'], oracle_autonomous_df_1w['Average Latency (millisecond)'],
         color='blue', linestyle='-', label='Average Latency - Oracle Autonomous DB Scale Factor=1')

# Plot average latency for single node
plt.plot(oracle_autonomous_df_10w['Time (seconds)'], oracle_autonomous_df_10w['Average Latency (millisecond)'],
         color='red', linestyle='-', label='Average Latency - Oracle Autonomous DB Scale Factor=10')

plt.plot(oracle_autonomous_df_100w['Time (seconds)'], oracle_autonomous_df_100w['Average Latency (millisecond)'],
         color='green', linestyle='-', label='Average Latency - Oracle Autonomous DB Scale Factor=100')

plt.xlabel('Time (seconds)')
plt.ylabel('Latency (millisecond)')
plt.title('Latency Comparison')
plt.legend()
plt.grid(True)
plt.show()
